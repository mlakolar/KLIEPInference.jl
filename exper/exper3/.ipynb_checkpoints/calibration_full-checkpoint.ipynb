# %% [markdown]
# # Calibration

# %%
using JLD, PyPlot

# %%
α = 0.05:0.05:0.95;

# %% [markdown]
# ## `m = 25, sgn = -1`

# %%
file = jldopen("res/coverage_25_-1.jld", "r")
coverage = read(file, "coverage")
coverage = broadcast(/, coverage, 1000)
close(file)

figure(figsize = (10, 5))

subplot(2, 4, 1)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[1, :], marker="o")
title("SparKLIE+1 full", size="xx-small")

subplot(2, 4, 2)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[2, :], marker="o")
title("SparKLIE+1 lite w/o bias correction", size="xx-small")

subplot(2, 4, 3)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[3, :], marker="o")
title("SparKLIE+1 lite w/  bias correction", size="xx-small")

subplot(2, 4, 4)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[4, :], marker="o")
title("SparKLIE+1 zero", size="xx-small")

subplot(2, 4, 5)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[5, :], marker="o")
title("SparKLIE+2 full", size="xx-small")

subplot(2, 4, 6)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[6, :], marker="o")
title("SparKLIE+2 zero", size="xx-small")

subplot(2, 4, 7)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[1, :], coverage[5, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 full", size="xx-small")

subplot(2, 4, 8)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[4, :], coverage[6, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 zero", size="xx-small")

tight_layout()
# Out:
# Figure(PyObject <Figure size 1000x500 with 8 Axes>)

# %% [markdown]
# ## `m = 25, sgn = 0`

# %%
file = jldopen("res/coverage_25_0.jld", "r")
coverage = read(file, "coverage")
coverage = broadcast(/, coverage, 1000)
close(file)

figure(figsize = (10, 5))

subplot(2, 4, 1)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[1, :], marker="o")
title("SparKLIE+1 full", size="xx-small")

subplot(2, 4, 2)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[2, :], marker="o")
title("SparKLIE+1 lite w/o bias correction", size="xx-small")

subplot(2, 4, 3)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[3, :], marker="o")
title("SparKLIE+1 lite w/  bias correction", size="xx-small")

subplot(2, 4, 4)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[4, :], marker="o")
title("SparKLIE+1 zero", size="xx-small")

subplot(2, 4, 5)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[5, :], marker="o")
title("SparKLIE+2 full", size="xx-small")

subplot(2, 4, 6)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[6, :], marker="o")
title("SparKLIE+2 zero", size="xx-small")

subplot(2, 4, 7)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[1, :], coverage[5, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 full", size="xx-small")

subplot(2, 4, 8)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[4, :], coverage[6, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 zero", size="xx-small")

tight_layout()
# Out:
# Figure(PyObject <Figure size 1000x500 with 8 Axes>)

# %% [markdown]
# ## `m = 25, sgn = 1`

# %%
file = jldopen("res/coverage_25_1.jld", "r")
coverage = read(file, "coverage")
coverage = broadcast(/, coverage, 1000)
close(file)

figure(figsize = (10, 5))

subplot(2, 4, 1)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[1, :], marker="o")
title("SparKLIE+1 full", size="xx-small")

subplot(2, 4, 2)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[2, :], marker="o")
title("SparKLIE+1 lite w/o bias correction", size="xx-small")

subplot(2, 4, 3)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[3, :], marker="o")
title("SparKLIE+1 lite w/  bias correction", size="xx-small")

subplot(2, 4, 4)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[4, :], marker="o")
title("SparKLIE+1 zero", size="xx-small")

subplot(2, 4, 5)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[5, :], marker="o")
title("SparKLIE+2 full", size="xx-small")

subplot(2, 4, 6)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[6, :], marker="o")
title("SparKLIE+2 zero", size="xx-small")

subplot(2, 4, 7)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[1, :], coverage[5, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 full", size="xx-small")

subplot(2, 4, 8)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[4, :], coverage[6, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 zero", size="xx-small")

tight_layout()
# Out:
# Figure(PyObject <Figure size 1000x500 with 8 Axes>)

# %% [markdown]
# ## `m = 50, sgn = -1`

# %%
file = jldopen("res/coverage_50_-1.jld", "r")
coverage = read(file, "coverage")
coverage = broadcast(/, coverage, 1000)
close(file)

figure(figsize = (10, 5))

subplot(2, 4, 1)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[1, :], marker="o")
title("SparKLIE+1 full", size="xx-small")

subplot(2, 4, 2)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[2, :], marker="o")
title("SparKLIE+1 lite w/o bias correction", size="xx-small")

subplot(2, 4, 3)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[3, :], marker="o")
title("SparKLIE+1 lite w/  bias correction", size="xx-small")

subplot(2, 4, 4)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[4, :], marker="o")
title("SparKLIE+1 zero", size="xx-small")

subplot(2, 4, 5)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[5, :], marker="o")
title("SparKLIE+2 full", size="xx-small")

subplot(2, 4, 6)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[6, :], marker="o")
title("SparKLIE+2 zero", size="xx-small")

subplot(2, 4, 7)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[1, :], coverage[5, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 full", size="xx-small")

subplot(2, 4, 8)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[4, :], coverage[6, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 zero", size="xx-small")

tight_layout()
# Out:
# Figure(PyObject <Figure size 1000x500 with 8 Axes>)

# %% [markdown]
# ## `m = 50, sgn = 0`

# %%
file = jldopen("res/coverage_50_0.jld", "r")
coverage = read(file, "coverage")
coverage = broadcast(/, coverage, 1000)
close(file)

figure(figsize = (10, 5))

subplot(2, 4, 1)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[1, :], marker="o")
title("SparKLIE+1 full", size="xx-small")

subplot(2, 4, 2)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[2, :], marker="o")
title("SparKLIE+1 lite w/o bias correction", size="xx-small")

subplot(2, 4, 3)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[3, :], marker="o")
title("SparKLIE+1 lite w/  bias correction", size="xx-small")

subplot(2, 4, 4)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[4, :], marker="o")
title("SparKLIE+1 zero", size="xx-small")

subplot(2, 4, 5)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[5, :], marker="o")
title("SparKLIE+2 full", size="xx-small")

subplot(2, 4, 6)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[6, :], marker="o")
title("SparKLIE+2 zero", size="xx-small")

subplot(2, 4, 7)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[1, :], coverage[5, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 full", size="xx-small")

subplot(2, 4, 8)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(coverage[4, :], coverage[6, :], marker="o")
title("SparKLIE+1 vs SparKLIE+2 zero", size="xx-small")

tight_layout()
# Out:
# Figure(PyObject <Figure size 1000x500 with 8 Axes>)

# %% [markdown]
# ## `m = 50, sgn = 1`

# %%
file = jldopen("res/coverage_50_1.jld", "r")
coverage = read(file, "coverage")
coverage = broadcast(/, coverage, 1000)
close(file)

figure(figsize = (9, 3))

subplot(1, 3, 1)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[1, :], marker="o")
title("SparKLIE+1 zero", size="xx-small")

subplot(1, 3, 2)
plot(1.0 .- α, 1.0 .- α, color="grey", linestyle=":", linewidth=.25)
plot(1.0 .- α, coverage[2, :], marker="o")
title("SparKLIE+2 zero", size="xx-small")

subplot(1, 3, 3)
plot(coverage[3, :], marker="o")
title("SparKLIE+1 zero == SparKLIE+2 zero", size="xx-small")

tight_layout()
# Out:
# Figure(PyObject <Figure size 900x300 with 3 Axes>)
